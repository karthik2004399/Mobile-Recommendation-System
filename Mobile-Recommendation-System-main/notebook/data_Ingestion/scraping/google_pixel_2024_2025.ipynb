# %% [markdown]
# # Google Pixel Phones Scraping (2024-2026)

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import json
import time
import re

# %% [markdown]
# ## Google Pixel 9 Series (2024)

# %%
# Google Pixel 9 Series
pixel_9_series = [
    {
        "name": "Google Pixel 9 Pro (Obsidian, 256 GB)",
        "brand": "Google",
        "price": 899,
        "processor": "Google Tensor G4",
        "ram_gb": 16,
        "storage_gb": 256,
        "rear_camera_mp": 50,
        "front_camera_mp": 42,
        "battery_mah": 4700,
        "screen_size": 6.3,
        "display_type": "OLED",
        "refresh_rate": 120,
        "5g": True,
        "fast_charging_watt": 45,
        "ratings": 4.7
    },
    {
        "name": "Google Pixel 9 Pro (Porcelain, 256 GB)",
        "brand": "Google",
        "price": 899,
        "processor": "Google Tensor G4",
        "ram_gb": 16,
        "storage_gb": 256,
        "rear_camera_mp": 50,
        "front_camera_mp": 42,
        "battery_mah": 4700,
        "screen_size": 6.3,
        "display_type": "OLED",
        "refresh_rate": 120,
        "5g": True,
        "fast_charging_watt": 45,
        "ratings": 4.7
    },
    {
        "name": "Google Pixel 9 Pro XL (Obsidian, 256 GB)",
        "brand": "Google",
        "price": 999,
        "processor": "Google Tensor G4",
        "ram_gb": 16,
        "storage_gb": 256,
        "rear_camera_mp": 50,
        "front_camera_mp": 42,
        "battery_mah": 5060,
        "screen_size": 6.8,
        "display_type": "OLED",
        "refresh_rate": 120,
        "5g": True,
        "fast_charging_watt": 45,
        "ratings": 4.8
    },
    {
        "name": "Google Pixel 9 (Obsidian, 128 GB)",
        "brand": "Google",
        "price": 699,
        "processor": "Google Tensor G4",
        "ram_gb": 12,
        "storage_gb": 128,
        "rear_camera_mp": 50,
        "front_camera_mp": 10.5,
        "battery_mah": 4700,
        "screen_size": 6.3,
        "display_type": "OLED",
        "refresh_rate": 120,
        "5g": True,
        "fast_charging_watt": 27,
        "ratings": 4.6
    },
    {
        "name": "Google Pixel 9 (Porcelain, 128 GB)",
        "brand": "Google",
        "price": 699,
        "processor": "Google Tensor G4",
        "ram_gb": 12,
        "storage_gb": 128,
        "rear_camera_mp": 50,
        "front_camera_mp": 10.5,
        "battery_mah": 4700,
        "screen_size": 6.3,
        "display_type": "OLED",
        "refresh_rate": 120,
        "5g": True,
        "fast_charging_watt": 27,
        "ratings": 4.6
    }
]

# %% [markdown]
# ## Google Pixel 8 Series (2023)

# %%
# Google Pixel 8 Series
pixel_8_series = [
    {
        "name": "Google Pixel 8 Pro (Obsidian, 256 GB)",
        "brand": "Google",
        "price": 799,
        "processor": "Google Tensor G3",
        "ram_gb": 12,
        "storage_gb": 256,
        "rear_camera_mp": 50,
        "front_camera_mp": 10.5,
        "battery_mah": 5050,
        "screen_size": 6.7,
        "display_type": "OLED",
        "refresh_rate": 120,
        "5g": True,
        "fast_charging_watt": 30,
        "ratings": 4.6
    },
    {
        "name": "Google Pixel 8 (Obsidian, 128 GB)",
        "brand": "Google",
        "price": 599,
        "processor": "Google Tensor G3",
        "ram_gb": 8,
        "storage_gb": 128,
        "rear_camera_mp": 50,
        "front_camera_mp": 10.5,
        "battery_mah": 4575,
        "screen_size": 6.2,
        "display_type": "OLED",
        "refresh_rate": 120,
        "5g": True,
        "fast_charging_watt": 27,
        "ratings": 4.5
    }
]

# %% [markdown]
# ## Google Pixel 9a (2025)

# %%
# Google Pixel 9a (March 2025)
pixel_9a = [
    {
        "name": "Google Pixel 9a (Obsidian, 128 GB)",
        "brand": "Google",
        "price": 499,
        "processor": "Google Tensor G4",
        "ram_gb": 8,
        "storage_gb": 128,
        "rear_camera_mp": 48,
        "front_camera_mp": 13,
        "battery_mah": 5100,
        "screen_size": 6.3,
        "display_type": "OLED",
        "refresh_rate": 120,
        "5g": True,
        "fast_charging_watt": 23,
        "ratings": 4.5
    },
    {
        "name": "Google Pixel 9a (Porcelain, 128 GB)",
        "brand": "Google",
        "price": 499,
        "processor": "Google Tensor G4",
        "ram_gb": 8,
        "storage_gb": 128,
        "rear_camera_mp": 48,
        "front_camera_mp": 13,
        "battery_mah": 5100,
        "screen_size": 6.3,
        "display_type": "OLED",
        "refresh_rate": 120,
        "5g": True,
        "fast_charging_watt": 23,
        "ratings": 4.5
    },
    {
        "name": "Google Pixel 9a (Iris, 128 GB)",
        "brand": "Google",
        "price": 499,
        "processor": "Google Tensor G4",
        "ram_gb": 8,
        "storage_gb": 128,
        "rear_camera_mp": 48,
        "front_camera_mp": 13,
        "battery_mah": 5100,
        "screen_size": 6.3,
        "display_type": "OLED",
        "refresh_rate": 120,
        "5g": True,
        "fast_charging_watt": 23,
        "ratings": 4.5
    }
]

# %% [markdown]
# ## Combine All Pixel Phones

# %%
# Combine all Pixel phones
all_pixel_phones = pixel_9_series + pixel_8_series + pixel_9a
df_pixel = pd.DataFrame(all_pixel_phones)

# Create corpus for similarity
df_pixel['corpus'] = (
    df_pixel['name'] + ' ' +
    df_pixel['processor'] + ' ' +
    df_pixel['ram_gb'].astype(str) + 'GB RAM ' +
    df_pixel['storage_gb'].astype(str) + 'GB Storage ' +
    df_pixel['rear_camera_mp'].astype(str) + 'MP Camera '
)

print(f"Total Google Pixel phones: {len(df_pixel)}")
df_pixel

# %%
# Save to CSV
df_pixel.to_csv('data/processed/google_pixel_2024_2025.csv', index=False)
print("Saved to data/processed/google_pixel_2024_2025.csv")
