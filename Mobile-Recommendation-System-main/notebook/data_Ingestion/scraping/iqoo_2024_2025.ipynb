# %% [markdown]
# # iQOO Phones Scraping (2024-2025)

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## iQOO 13 Series (2024-2025)

# %%
# iQOO 13 Series
iqoo_phones = [
    {
        "name": "iQOO 13 (Legend, 256 GB)",
        "brand": "iQOO",
        "price": 599,
        "processor": "Snapdragon 8 Elite",
        "ram_gb": 12,
        "storage_gb": 256,
        "rear_camera_mp": 50,
        "front_camera_mp": 32,
        "battery_mah": 6000,
        "screen_size": 6.82,
        "display_type": "AMOLED",
        "refresh_rate": 144,
        "5g": True,
        "fast_charging_watt": 120,
        "ratings": 4.7
    },
    {
        "name": "iQOO 13 (Nardo Grey, 256 GB)",
        "brand": "iQOO",
        "price": 599,
        "processor": "Snapdragon 8 Elite",
        "ram_gb": 12,
        "storage_gb": 256,
        "rear_camera_mp": 50,
        "front_camera_mp": 32,
        "battery_mah": 6000,
        "screen_size": 6.82,
        "display_type": "AMOLED",
        "refresh_rate": 144,
        "5g": True,
        "fast_charging_watt": 120,
        "ratings": 4.7
    },
    {
        "name": "iQOO 13 (Phantom Green, 512 GB)",
        "brand": "iQOO",
        "price": 699,
        "processor": "Snapdragon 8 Elite",
        "ram_gb": 16,
        "storage_gb": 512,
        "rear_camera_mp": 50,
        "front_camera_mp": 32,
        "battery_mah": 6000,
        "screen_size": 6.82,
        "display_type": "AMOLED",
        "refresh_rate": 144,
        "5g": True,
        "fast_charging_watt": 120,
        "ratings": 4.8
    }
]

# %% [markdown]
# ## iQOO Neo Series (2024)

# %%
# iQOO Neo 10 Series
iqoo_neo = [
    {
        "name": "iQOO Neo 10 (Alpha, 256 GB)",
        "brand": "iQOO",
        "price": 399,
        "processor": "Snapdragon 8 Gen 3",
        "ram_gb": 12,
        "storage_gb": 256,
        "rear_camera_mp": 50,
        "front_camera_mp": 16,
        "battery_mah": 6100,
        "screen_size": 6.78,
        "display_type": "AMOLED",
        "refresh_rate": 144,
        "5g": True,
        "fast_charging_watt": 120,
        "ratings": 4.6
    },
    {
        "name": "iQOO Neo 10 Pro (Alpha, 256 GB)",
        "brand": "iQOO",
        "price": 449,
        "processor": "Dimensity 9400",
        "ram_gb": 12,
        "storage_gb": 256,
        "rear_camera_mp": 50,
        "front_camera_mp": 16,
        "battery_mah": 6100,
        "screen_size": 6.78,
        "display_type": "AMOLED",
        "refresh_rate": 144,
        "5g": True,
        "fast_charging_watt": 120,
        "ratings": 4.7
    }
]

# %% [markdown]
# ## iQOO Z9 Series (2024)

# %%
# iQOO Z9 Series
iqoo_z9 = [
    {
        "name": "iQOO Z9 (Graphite, 128 GB)",
        "brand": "iQOO",
        "price": 199,
        "processor": "Dimensity 7200",
        "ram_gb": 8,
        "storage_gb": 128,
        "rear_camera_mp": 50,
        "front_camera_mp": 16,
        "battery_mah": 5000,
        "screen_size": 6.67,
        "display_type": "AMOLED",
        "refresh_rate": 120,
        "5g": True,
        "fast_charging_watt": 44,
        "ratings": 4.4
    },
    {
        "name": "iQOO Z9x (Graphite, 128 GB)",
        "brand": "iQOO",
        "price": 179,
        "processor": "Snapdragon 6 Gen 1",
        "ram_gb": 8,
        "storage_gb": 128,
        "rear_camera_mp": 50,
        "front_camera_mp": 8,
        "battery_mah": 6000,
        "screen_size": 6.72,
        "display_type": "LCD",
        "refresh_rate": 120,
        "5g": True,
        "fast_charging_watt": 44,
        "ratings": 4.3
    }
]

# %% [markdown]
# ## Combine All iQOO Phones

# %%
# Combine all iQOO phones
all_iqoo_phones = iqoo_phones + iqoo_neo + iqoo_z9
df_iqoo = pd.DataFrame(all_iqoo_phones)

# Create corpus for similarity
df_iqoo['corpus'] = (
    df_iqoo['name'] + ' ' +
    df_iqoo['processor'] + ' ' +
    df_iqoo['ram_gb'].astype(str) + 'GB RAM ' +
    df_iqoo['storage_gb'].astype(str) + 'GB Storage ' +
    df_iqoo['rear_camera_mp'].astype(str) + 'MP Camera '
)

print(f"Total iQOO phones: {len(df_iqoo)}")
df_iqoo

# %%
# Save to CSV
df_iqoo.to_csv('data/processed/iqoo_2024_2025.csv', index=False)
print("Saved to data/processed/iqoo_2024_2025.csv")
