# %% [markdown]
# # Nothing Phones Scraping (2024-2025)

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## Nothing Phone 3 Series (2025)

# %%
# Nothing Phone 3 Series
nothing_phones = [
    {
        "name": "Nothing Phone 3a Pro (Dark, 256 GB)",
        "brand": "Nothing",
        "price": 379,
        "processor": "Snapdragon 7s Gen 2",
        "ram_gb": 12,
        "storage_gb": 256,
        "rear_camera_mp": 50,
        "front_camera_mp": 32,
        "battery_mah": 5000,
        "screen_size": 6.77,
        "display_type": "AMOLED",
        "refresh_rate": 120,
        "5g": True,
        "fast_charging_watt": 45,
        "ratings": 4.5
    },
    {
        "name": "Nothing Phone 3a Pro (White, 256 GB)",
        "brand": "Nothing",
        "price": 379,
        "processor": "Snapdragon 7s Gen 2",
        "ram_gb": 12,
        "storage_gb": 256,
        "rear_camera_mp": 50,
        "front_camera_mp": 32,
        "battery_mah": 5000,
        "screen_size": 6.77,
        "display_type": "AMOLED",
        "refresh_rate": 120,
        "5g": True,
        "fast_charging_watt": 45,
        "ratings": 4.5
    },
    {
        "name": "Nothing Phone 3a (Dark, 128 GB)",
        "brand": "Nothing",
        "price": 279,
        "processor": "Snapdragon 7s Gen 2",
        "ram_gb": 8,
        "storage_gb": 128,
        "rear_camera_mp": 50,
        "front_camera_mp": 16,
        "battery_mah": 5000,
        "screen_size": 6.77,
        "display_type": "AMOLED",
        "refresh_rate": 120,
        "5g": True,
        "fast_charging_watt": 45,
        "ratings": 4.4
    }
]

# %% [markdown]
# ## Nothing Phone 2a (2024)

# %%
# Nothing Phone 2a
nothing_2a = [
    {
        "name": "Nothing Phone 2a (White, 128 GB)",
        "brand": "Nothing",
        "price": 239,
        "processor": "Dimensity 7200 Pro",
        "ram_gb": 8,
        "storage_gb": 128,
        "rear_camera_mp": 50,
        "front_camera_mp": 32,
        "battery_mah": 5000,
        "screen_size": 6.7,
        "display_type": "AMOLED",
        "refresh_rate": 120,
        "5g": True,
        "fast_charging_watt": 45,
        "ratings": 4.4
    },
    {
        "name": "Nothing Phone 2a (Blue, 128 GB)",
        "brand": "Nothing",
        "price": 239,
        "processor": "Dimensity 7200 Pro",
        "ram_gb": 8,
        "storage_gb": 128,
        "rear_camera_mp": 50,
        "front_camera_mp": 32,
        "battery_mah": 5000,
        "screen_size": 6.7,
        "display_type": "AMOLED",
        "refresh_rate": 120,
        "5g": True,
        "fast_charging_watt": 45,
        "ratings": 4.4
    }
]

# %% [markdown]
# ## Combine All Nothing Phones

# %%
# Combine all Nothing phones
all_nothing_phones = nothing_phones + nothing_2a
df_nothing = pd.DataFrame(all_nothing_phones)

# Create corpus for similarity
df_nothing['corpus'] = (
    df_nothing['name'] + ' ' +
    df_nothing['processor'] + ' ' +
    df_nothing['ram_gb'].astype(str) + 'GB RAM ' +
    df_nothing['storage_gb'].astype(str) + 'GB Storage ' +
    df_nothing['rear_camera_mp'].astype(str) + 'MP Camera '
)

print(f"Total Nothing phones: {len(df_nothing)}")
df_nothing

# %%
# Save to CSV
df_nothing.to_csv('data/processed/nothing_2024_2025.csv', index=False)
print("Saved to data/processed/nothing_2024_2025.csv")
